# %%
from neo4j import GraphDatabase, basic_auth
import nxneo4j as nx #using nxneo4j
from py2neo import Graph, Node
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\xampp\htdocs\Maltese Food Network Analysis\Maltese-Food-Network-Analysis\Website\Querys\GetPopularIngredient.ipynb Cell 1' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/Maltese%20Food%20Network%20Analysis/Maltese-Food-Network-Analysis/Website/Querys/GetPopularIngredient.ipynb#ch0000000?line=0'>1</a> from neo4j import GraphDatabase, basic_auth
#       <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/Maltese%20Food%20Network%20Analysis/Maltese-Food-Network-Analysis/Website/Querys/GetPopularIngredient.ipynb#ch0000000?line=1'>2</a> import nxneo4j as nx #using nxneo4j
#       <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/Maltese%20Food%20Network%20Analysis/Maltese-Food-Network-Analysis/Website/Querys/GetPopularIngredient.ipynb#ch0000000?line=2'>3</a> from py2neo import Graph, Node
#
# ImportError: cannot import name 'GraphDatabase' from 'neo4j' (C:\Users\maxma\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\neo4j\__init__.py)

# %%
cGraph = Graph("neo4j+s://101fd6b7.databases.neo4j.io", auth=('neo4j', "gB9F-fD2doYqInIcXR3DJZwnvvDWm-ZpgvOJ3BGCl54"))

query = "MATCH (i:Ingredient)-[r:inRecipe]-(c:Recipe) RETURN i.name, count(r) AS connections ORDER BY connections DESC"

result = cGraph.query(query)
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\py2neo\database.py:88, in Database.__new__(cls, uri, **settings)
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=86'>87</a> try:
# ---> <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=87'>88</a>     inst = cls._instances[key]
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=88'>89</a> except KeyError:
#
# KeyError: 'bb2a6ca8f7ef40eaf05092485996016f'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\xampp\htdocs\Maltese Food Network Analysis\Maltese-Food-Network-Analysis\Website\Querys\GetPopularIngredient.ipynb Cell 2' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/Maltese%20Food%20Network%20Analysis/Maltese-Food-Network-Analysis/Website/Querys/GetPopularIngredient.ipynb#ch0000001?line=0'>1</a> cGraph = Graph("neo4j+s://101fd6b7.databases.neo4j.io", auth=('neo4j', "gB9F-fD2doYqInIcXR3DJZwnvvDWm-ZpgvOJ3BGCl54"))
#       <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/Maltese%20Food%20Network%20Analysis/Maltese-Food-Network-Analysis/Website/Querys/GetPopularIngredient.ipynb#ch0000001?line=2'>3</a> query = "MATCH (i:Ingredient)-[r:inRecipe]-(c:Recipe) RETURN i.name, count(r) AS connections ORDER BY connections DESC"
#       <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/Maltese%20Food%20Network%20Analysis/Maltese-Food-Network-Analysis/Website/Querys/GetPopularIngredient.ipynb#ch0000001?line=4'>5</a> result = cGraph.query(query)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\py2neo\database.py:305, in Graph.__new__(cls, uri, **settings)
#     <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=302'>303</a> def __new__(cls, uri=None, **settings):
#     <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=303'>304</a>     name = settings.pop("name", "data")
# --> <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=304'>305</a>     database = Database(uri, **settings)
#     <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=305'>306</a>     if name in database:
#     <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=306'>307</a>         inst = database[name]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\py2neo\database.py:92, in Database.__new__(cls, uri, **settings)
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=89'>90</a> inst = super(Database, cls).__new__(cls)
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=90'>91</a> inst._connection_data = connection_data
# ---> <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=91'>92</a> from py2neo.internal.http import HTTPDriver, HTTPSDriver
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=92'>93</a> from neo4j.v1 import Driver
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=93'>94</a> inst._driver = Driver(connection_data["uri"],
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=94'>95</a>                       auth=connection_data["auth"],
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=95'>96</a>                       encrypted=connection_data["secure"],
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/database.py?line=96'>97</a>                       user_agent=connection_data["user_agent"])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\py2neo\internal\http.py:29, in <module>
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/internal/http.py?line=26'>27</a> from neo4j.bolt import ServerInfo
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/internal/http.py?line=27'>28</a> from neo4j.exceptions import AuthError, Forbidden
# ---> <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/internal/http.py?line=28'>29</a> from neo4j.v1 import Driver, Session, StatementResult, TransactionError, SessionError
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/internal/http.py?line=30'>31</a> from py2neo.data import Record
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/py2neo/internal/http.py?line=31'>32</a> from py2neo.database import GraphError
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\neo4j\v1\__init__.py:25, in <module>
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/neo4j/v1/__init__.py?line=22'>23</a> from .exceptions import *
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/neo4j/v1/__init__.py?line=23'>24</a> from .result import *
# ---> <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/neo4j/v1/__init__.py?line=24'>25</a> from .routing import *
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/neo4j/v1/__init__.py?line=25'>26</a> from .security import *
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/neo4j/v1/__init__.py?line=26'>27</a> from .types import *
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\neo4j\v1\routing.py:25, in <module>
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/neo4j/v1/routing.py?line=22'>23</a> from sys import maxsize
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/neo4j/v1/routing.py?line=23'>24</a> from threading import Lock
# ---> <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/neo4j/v1/routing.py?line=24'>25</a> from time import clock
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/neo4j/v1/routing.py?line=26'>27</a> from neo4j.addressing import SocketAddress
#      <a href='file:///c%3A/Users/maxma/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/neo4j/v1/routing.py?line=27'>28</a> from neo4j.bolt import ConnectionPool, ServiceUnavailable, ProtocolError, DEFAULT_PORT, connect, ConnectionErrorHandler
#
# ImportError: cannot import name 'clock' from 'time' (unknown location)
